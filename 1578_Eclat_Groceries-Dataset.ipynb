# %% [markdown]
# ### Mounting Drive

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing Dataset

# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv(
    "/content/drive/MyDrive/Dataset/MLL/groceries.csv", sep="\n", header=None
)[0].str.split(",", expand=True)
dataset.head()
# Out:
#                  0                    1               2   \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                 None            None
# 3         pip fruit               yogurt   cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                          3     4     5     6     7     8     9   ...    22  \
# 0               ready soups  None  None  None  None  None  None  ...  None
# 1                      None  None  None  None  None  None  None  ...  None
# 2                      None  None  None  None  None  None  None  ...  None
# 3              meat spreads  None  None  None  None  None  None  ...  None
# 4  long life bakery product  None  None  None  None  None  None  ...  None
#
#      23    24    25    26    27    28    29    30    31
# 0  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None
#
# [5 rows x 32 columns]

# %%
dataset.shape
# Out:
# (9835, 32)

# %% [markdown]
# ### Converting Pandas DataFrame into Lists of Transactions

# %%
transactions = []
for i in range(0, 9835):
    # transactions.append([str(dataset.values[i,j]) for j in range(0, 32)])
    transactions.append(
        [
            str(dataset.values[i, j])
            for j in range(0, 32)
            if str(dataset.values[i, j]) != "None"
        ]
    )
for i in range(0, 5):
    print(transactions[i])
# Out:
# ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups']
# ['tropical fruit', 'yogurt', 'coffee']
# ['whole milk']
# ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads']
# ['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product']

# %%
# converting the transaction list into a dataframe
data = pd.DataFrame(transactions)
data
# Out:
#                        0                    1                 2   \
# 0            citrus fruit  semi-finished bread         margarine
# 1          tropical fruit               yogurt            coffee
# 2              whole milk                 None              None
# 3               pip fruit               yogurt     cream cheese
# 4        other vegetables           whole milk    condensed milk
# ...                   ...                  ...               ...
# 9830              sausage              chicken              beef
# 9831    cooking chocolate                 None              None
# 9832              chicken         citrus fruit  other vegetables
# 9833  semi-finished bread        bottled water              soda
# 9834              chicken       tropical fruit  other vegetables
#
#                             3              4               5   \
# 0                  ready soups           None            None
# 1                         None           None            None
# 2                         None           None            None
# 3                 meat spreads           None            None
# 4     long life bakery product           None            None
# ...                        ...            ...             ...
# 9830            hamburger meat   citrus fruit          grapes
# 9831                      None           None            None
# 9832                    butter         yogurt  frozen dessert
# 9833              bottled beer           None            None
# 9834                   vinegar  shopping bags            None
#
#                    6           7       8                   9   ...    22  \
# 0                None        None    None                None  ...  None
# 1                None        None    None                None  ...  None
# 2                None        None    None                None  ...  None
# 3                None        None    None                None  ...  None
# 4                None        None    None                None  ...  None
# ...               ...         ...     ...                 ...  ...   ...
# 9830  root vegetables  whole milk  butter  whipped/sour cream  ...  None
# 9831             None        None    None                None  ...  None
# 9832    domestic eggs  rolls/buns     rum     cling film/bags  ...  None
# 9833             None        None    None                None  ...  None
# 9834             None        None    None                None  ...  None
#
#         23    24    25    26    27    28    29    30    31
# 0     None  None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...
# 9830  None  None  None  None  None  None  None  None  None
# 9831  None  None  None  None  None  None  None  None  None
# 9832  None  None  None  None  None  None  None  None  None
# 9833  None  None  None  None  None  None  None  None  None
# 9834  None  None  None  None  None  None  None  None  None
#
# [9835 rows x 32 columns]

# %% [markdown]
# ### Training the Eclat Model on the Dataset

# %%
# !pip install pyECLAT
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyECLAT in /usr/local/lib/python3.7/dist-packages (1.0.2)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from pyECLAT) (1.3.5)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from pyECLAT) (4.64.1)
# Requirement already satisfied: numpy>=1.17.4 in /usr/local/lib/python3.7/dist-packages (from pyECLAT) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->pyECLAT) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->pyECLAT) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->pyECLAT) (1.15.0)

# %%
from pyECLAT import ECLAT

min_support = 0.01
min_n_products = 2
max_length = 2

# create an instance of eclat
my_eclat = ECLAT(data=data, verbose=True)

# fit the algorithm
rule_indices, rule_supports = my_eclat.fit(
    min_support=min_support, min_combination=min_n_products, max_combination=max_length
)
# Out:
# 100%|██████████| 170/170 [00:04<00:00, 39.73it/s]
# 100%|██████████| 170/170 [00:00<00:00, 1806.18it/s]
# 100%|██████████| 170/170 [00:00<00:00, 2606.39it/s]
# Combination 2 by 2
# 3828it [00:47, 80.72it/s]

# %%
print(rule_supports)
# Out:
# {'beef & whole milk': 0.02125063548551093, 'beef & rolls/buns': 0.01362480935434672, 'beef & other vegetables': 0.019725470259278087, 'beef & root vegetables': 0.017386883579054397, 'beef & yogurt': 0.011692933401118455, 'butter milk & whole milk': 0.011591255719369599, 'butter milk & other vegetables': 0.010371123538383325, 'sausage & bottled water': 0.011997966446365024, 'sausage & soda': 0.024300965937976614, 'sausage & pip fruit': 0.010777834265378749, 'sausage & fruit/vegetable juice': 0.010066090493136757, 'sausage & whole milk': 0.0298932384341637, 'sausage & pastry': 0.012506354855109304, 'sausage & brown bread': 0.010676156583629894, 'sausage & tropical fruit': 0.013929842399593289, 'sausage & rolls/buns': 0.030604982206405694, 'sausage & shopping bags': 0.015658362989323844, 'sausage & other vegetables': 0.026944585663446874, 'sausage & frankfurter': 0.010066090493136757, 'sausage & root vegetables': 0.01494661921708185, 'sausage & yogurt': 0.019623792577529234, 'sausage & citrus fruit': 0.01128622267412303, 'long life bakery product & whole milk': 0.013523131672597865, 'long life bakery product & other vegetables': 0.010676156583629894, 'bottled water & soda': 0.028978139298423997, 'bottled water & pip fruit': 0.010574478901881037, 'bottled water & fruit/vegetable juice': 0.014234875444839857, 'bottled water & whole milk': 0.03436705643111337, 'bottled water & newspapers': 0.01128622267412303, 'bottled water & tropical fruit': 0.018505338078291814, 'bottled water & rolls/buns': 0.024199288256227757, 'bottled water & shopping bags': 0.010981189628876462, 'bottled water & bottled beer': 0.0157600406710727, 'bottled water & margarine': 0.010269445856634469, 'bottled water & other vegetables': 0.024809354346720894, 'bottled water & root vegetables': 0.015658362989323844, 'bottled water & yogurt': 0.022979156075241484, 'bottled water & citrus fruit': 0.013523131672597865, 'soda & pip fruit': 0.013319776309100152, 'soda & whipped/sour cream': 0.011591255719369599, 'soda & domestic eggs': 0.012404677173360447, 'soda & fruit/vegetable juice': 0.01840366039654296, 'soda & whole milk': 0.040061006609049314, 'soda & pastry': 0.021047280122013217, 'soda & white bread': 0.010269445856634469, 'soda & brown bread': 0.01260803253685816, 'soda & newspapers': 0.014641586171835282, 'soda & tropical fruit': 0.020843924758515507, 'soda & rolls/buns': 0.03833248601931876, 'soda & chocolate': 0.013523131672597865, 'soda & shopping bags': 0.024605998983223184, 'soda & napkins': 0.011997966446365024, 'soda & bottled beer': 0.016980172852058974, 'soda & margarine': 0.010167768174885612, 'soda & other vegetables': 0.032740213523131674, 'soda & pork': 0.011896288764616167, 'soda & canned beer': 0.013828164717844434, 'soda & frankfurter': 0.01128622267412303, 'soda & root vegetables': 0.01860701576004067, 'soda & yogurt': 0.027351296390442297, 'soda & citrus fruit': 0.012811387900355872, 'pip fruit & whole milk': 0.030096593797661414, 'pip fruit & pastry': 0.010676156583629894, 'pip fruit & tropical fruit': 0.02043721403152008, 'pip fruit & rolls/buns': 0.013929842399593289, 'pip fruit & other vegetables': 0.026131164209456024, 'pip fruit & root vegetables': 0.015556685307574987, 'pip fruit & yogurt': 0.017996949669547534, 'pip fruit & citrus fruit': 0.013828164717844434, 'whipped/sour cream & whole milk': 0.032231825114387394, 'whipped/sour cream & butter': 0.010167768174885612, 'whipped/sour cream & tropical fruit': 0.013828164717844434, 'whipped/sour cream & rolls/buns': 0.014641586171835282, 'whipped/sour cream & curd': 0.01047280122013218, 'whipped/sour cream & other vegetables': 0.02887646161667514, 'whipped/sour cream & root vegetables': 0.01708185053380783, 'whipped/sour cream & yogurt': 0.02074224707676665, 'whipped/sour cream & citrus fruit': 0.010879511947127605, 'domestic eggs & whole milk': 0.029994916115912557, 'domestic eggs & tropical fruit': 0.011387900355871887, 'domestic eggs & rolls/buns': 0.015658362989323844, 'domestic egg ...

# %%
results = rule_supports
results
# Out:
# {'beef & whole milk': 0.02125063548551093,
#  'beef & rolls/buns': 0.01362480935434672,
#  'beef & other vegetables': 0.019725470259278087,
#  'beef & root vegetables': 0.017386883579054397,
#  'beef & yogurt': 0.011692933401118455,
#  'butter milk & whole milk': 0.011591255719369599,
#  'butter milk & other vegetables': 0.010371123538383325,
#  'sausage & bottled water': 0.011997966446365024,
#  'sausage & soda': 0.024300965937976614,
#  'sausage & pip fruit': 0.010777834265378749,
#  'sausage & fruit/vegetable juice': 0.010066090493136757,
#  'sausage & whole milk': 0.0298932384341637,
#  'sausage & pastry': 0.012506354855109304,
#  'sausage & brown bread': 0.010676156583629894,
#  'sausage & tropical fruit': 0.013929842399593289,
#  'sausage & rolls/buns': 0.030604982206405694,
#  'sausage & shopping bags': 0.015658362989323844,
#  'sausage & other vegetables': 0.026944585663446874,
#  'sausage & frankfurter': 0.010066090493136757,
#  'sausage & root vegetables': 0.01494661921708185,
#  'sausage & yogurt': 0.019623792577529234,
#  'sausage & citrus fruit': 0.01128622267412303,
#  'long life bakery product & whole milk': 0.013523131672597865,
#  'long life bakery product & other vegetables': 0.010676156583629894,
#  'bottled water & soda': 0.028978139298423997,
#  'bottled water & pip fruit': 0.010574478901881037,
#  'bottled water & fruit/vegetable juice': 0.014234875444839857,
#  'bottled water & whole milk': 0.03436705643111337,
#  'bottled water & newspapers': 0.01128622267412303,
#  'bottled water & tropical fruit': 0.018505338078291814,
#  'bottled water & rolls/buns': 0.024199288256227757,
#  'bottled water & shopping bags': 0.010981189628876462,
#  'bottled water & bottled beer': 0.0157600406710727,
#  'bottled water & margarine': 0.010269445856634469,
#  'bottled water & other vegetables': 0.024809354346720894,
#  'bottled water & root vegetables': 0.015658362989323844,
#  'bottled water & yogurt': 0.022979156075241484,
#  'bottled water & citrus fruit': 0.013523131672597865,
#  'soda & pip fruit': 0.013319776309100152,
#  'soda & whipped/sour cream': 0.011591255719369599,
#  'soda & domestic eggs': 0.012404677173360447,
#  'soda & fruit/vegetable juice': 0.01840366039654296,
#  'soda & whole milk': 0.040061006609049314,
#  'soda & pastry': 0.021047280122013217,
#  'soda & white bread': 0.010269445856634469,
#  'soda & brown bread': 0.01260803253685816,
#  'soda & newspapers': 0.014641586171835282,
#  'soda & tropical fruit': 0.020843924758515507,
#  'soda & rolls/buns': 0.03833248601931876,
#  'soda & chocolate': 0.013523131672597865,
#  'soda & shopping bags': 0.024605998983223184,
#  'soda & napkins': 0.011997966446365024,
#  'soda & bottled beer': 0.016980172852058974,
#  'soda & margarine': 0.010167768174885612,
#  'soda & other vegetables': 0.032740213523131674,
#  'soda & pork': 0.011896288764616167,
#  'soda & canned beer': 0.013828164717844434,
#  'soda & frankfurter': 0.01128622267412303,
#  'soda & root vegetables': 0.01860701576004067,
#  'soda & yogurt': 0.027351296390442297,
#  'soda & citrus fruit': 0.012811387900355872,
#  'pip fruit & whole milk': 0.030096593797661414,
#  'pip fruit & pastry': 0.010676156583629894,
#  'pip fruit & tropical fruit': 0.02043721403152008,
#  'pip fruit & rolls/buns': 0.013929842399593289,
#  'pip fruit & other vegetables': 0.026131164209456024,
#  'pip fruit & root vegetables': 0.015556685307574987,
#  'pip fruit & yogurt': 0.017996949669547534,
#  'pip fruit & citrus fruit': 0.013828164717844434,
#  'whipped/sour cream & whole milk': 0.032231825114387394,
#  'whipped/sour cream & butter': 0.010167768174885612,
#  'whipped/sour cream & tropical fruit': 0.013828164717844434,
#  'whipped/sour cream & rolls/buns': 0.014641586171835282,
#  'whipped/sour cream & curd': 0.01047280122013218,
#  'whipped/sour cream & other vegetables': 0.02887646161667514,
#  'whipped/sour cream & root vegetables': 0.01708185053380783,
#  'whipped/sour cream & yogurt': 0.02074224707676665,
#  'whipped/sour cream & citrus fruit': 0.010879511947127605,
#  'domestic eggs & whole milk': 0.029994916115912557,
#  'domestic eggs & tropical fruit': 0.011387900355871887,
#  'domestic eggs & rolls/buns': 0.015658362989323844,
#  'domestic eggs & other vegetables': 0.02226741230299949,
#  'domestic eggs & root vegetables': 0.014336553126588714,
#  'domestic eggs & yogurt': 0.014336553126588714,
#  'domestic eggs & citrus fruit': 0.010371123538383325,
#  'waffles & whole milk': 0.012709710218607015,
#  'waffles & other vegetables': 0.010066090493136757,
#  'fruit/vegetable juice & whole milk': 0.026639552618200304,
#  'fruit/vegetable juice & tropical fruit': 0.013726487036095577,
#  'fruit/vegetable juice & rolls/buns': 0.014539908490086425,
#  'fruit/vegetable juice & shopping bags': 0.010676156583629894,
#  'fruit/vegetable juice & other vegetables': 0.021047280122013217,
#  'fruit/vegetable juice & root vegetables': 0.011997966446365024,
#  'fruit/vegetable juice & yogurt': 0.018708693441789527,
#  'fruit/vegetable juice & citrus fruit': 0.010371123538383325,
#  'whole milk & pastry': 0.033248601931875954,
#  'whole milk & butter': 0.02755465175394001,
#  'whole milk & white bread': 0.01708185053380783,
#  'whole milk & brown bread': 0.02521606507371632,
#  'whole milk & sugar': 0.015048296898830707,
#  'whole milk & sliced cheese': 0.010777834265378749,
#  'whole milk & newspapers': 0.027351296390442297,
#  'whole milk & tropical fruit': 0.04229791560752415,
#  'whole milk & rolls/buns': 0.05663446873411286,
#  'whole milk & chocolate': 0.016675139806812404,
#  'whole milk & chicken': 0.01759023894255211,
#  'whole milk & onions': 0.012099644128113879,
#  'whole milk & hard cheese': 0.010066090493136757,
#  'whole milk & coffee': 0.018708693441789527,
#  'whole milk & shopping bags': 0.024504321301474327,
#  'whole milk & napkins': 0.019725470259278087,
#  'whole milk & ham': 0.011489578037620742,
#  'whole milk & frozen vegetables': 0.02043721403152008,
#  'whole milk & berries': 0.01179461108286731,
#  'whole milk & oil': 0.01128622267412303,
#  'whole milk & bottled beer': 0.02043721403152008,
#  'whole milk & margarine': 0.024199288256227757,
#  'whole milk & curd': 0.026131164209456024,
#  'whole milk & salty snack': 0.011184544992374174,
#  'whole milk & dessert': 0.013726487036095577,
#  'whole milk & other vegetables': 0.07483477376715811,
#  'whole milk & pork': 0.022165734621250637,
#  'whole milk & frankfurter': 0.020538891713268937,
#  'whole milk & hygiene articles': 0.012811387900355872,
#  'whole milk & root vegetables': 0.048906964921199794,
#  'whole milk & yogurt': 0.05602440264361973,
#  'whole milk & hamburger meat': 0.014743263853584139,
#  'whole milk & cream cheese ': 0.016471784443314694,
#  'whole milk & citrus fruit': 0.030503304524656837,
#  'pastry & tropical fruit': 0.013218098627351297,
#  'pastry & rolls/buns': 0.02094560244026436,
#  'pastry & shopping bags': 0.011896288764616167,
#  'pastry & other vegetables': 0.02257244534824606,
#  'pastry & root vegetables': 0.010981189628876462,
#  'pastry & yogurt': 0.017691916624300967,
#  'butter & rolls/buns': 0.013421453990849009,
#  'butter & other vegetables': 0.020030503304524657,
#  'butter & root vegetables': 0.012913065582104729,
#  'butter & yogurt': 0.014641586171835282,
#  'white bread & other vegetables': 0.013726487036095577,
#  'brown bread & tropical fruit': 0.010676156583629894,
#  'brown bread & rolls/buns': 0.01260803253685816,
#  'brown bread & other vegetables': 0.018708693441789527,
#  'brown bread & root vegetables': 0.010167768174885612,
#  'brown bread & yogurt': 0.014539908490086425,
#  'sugar & other vegetables': 0.010777834265378749,
#  'newspapers & tropical fruit': 0.01179461108286731,
#  'newspapers & rolls/buns': 0.019725470259278087,
#  'newspapers & other vegetables': 0.019318759532282664,
#  'newspapers & root vegetables': 0.011489578037620742,
#  'newspapers & yogurt': 0.015353329944077275,
#  'tropical fruit & rolls/buns': 0.024605998983223184,
#  'tropical fruit & shopping bags': 0.013523131672597865,
#  'tropical fruit & napkins': 0.010066090493136757,
#  'tropical fruit & curd': 0.010269445856634469,
#  'tropical fruit & other vegetables': 0.035892221657346214,
#  'tropical fruit & root vegetables': 0.021047280122013217,
#  'tropical fruit & yogurt': 0.029283172343670564,
#  'tropical fruit & citrus fruit': 0.0199288256227758,
#  'rolls/buns & chocolate': 0.01179461108286731,
#  'rolls/buns & coffee': 0.010981189628876462,
#  'rolls/buns & shopping bags': 0.019522114895780377,
#  'rolls/buns & napkins': 0.011692933401118455,
#  'rolls/buns & frozen vegetables': 0.010167768174885612,
#  'rolls/buns & bottled beer': 0.01362480935434672,
#  'rolls/buns & margarine': 0.014743263853584139,
#  'rolls/buns & curd': 0.010066090493136757,
#  'rolls/buns & other vegetables': 0.042602948652770714,
#  'rolls/buns & pork': 0.01128622267412303,
#  'rolls/buns & canned beer': 0.01128622267412303,
#  'rolls/buns & frankfurter': 0.019217081850533807,
#  'rolls/buns & root vegetables': 0.024300965937976614,
#  'rolls/buns & yogurt': 0.03436705643111337,
#  'rolls/buns & citrus fruit': 0.01677681748856126,
#  'chocolate & other vegetables': 0.012709710218607015,
#  'chicken & other vegetables': 0.017895271987798677,
#  'chicken & root vegetables': 0.010879511947127605,
#  'onions & other vegetables': 0.014234875444839857,
#  'coffee & other vegetables': 0.013421453990849009,
#  'shopping bags & other vegetables': 0.023182511438739197,
#  'shopping bags & canned beer': 0.011387900355871887,
#  'shopping bags & root vegetables': 0.012811387900355872,
#  'shopping bags & yogurt': 0.015251652262328419,
#  'napkins & other vegetables': 0.01443823080833757,
#  'napkins & yogurt': 0.012302999491611592,
#  'frozen vegetables & other vegetables': 0.017793594306049824,
#  'frozen vegetables & root vegetables': 0.011591255719369599,
#  'frozen vegetables & yogurt': 0.012404677173360447,
#  'berries & other vegetables': 0.010269445856634469,
#  'berries & yogurt': 0.010574478901881037,
#  'bottled beer & other vegetables': 0.016166751398068124,
#  'margarine & other vegetables': 0.019725470259278087,
#  'margarine & root vegetables': 0.011082867310625319,
#  'margarine & yogurt': 0.014234875444839857,
#  'curd & other vegetables': 0.017183528215556684,
#  'curd & root vegetables': 0.010879511947127605,
#  'curd & yogurt': 0.01728520589730554,
#  'salty snack & other vegetables': 0.010777834265378749,
#  'dessert & other vegetables': 0.011591255719369599,
#  'other vegetables & pork': 0.021657346212506354,
#  'other vegetables & frankfurter': 0.016471784443314694,
#  'other vegetables & root vegetables': 0.047381799694966954,
#  'other vegetables & yogurt': 0.04341637010676157,
#  'other vegetables & hamburger meat': 0.013828164717844434,
#  'other vegetables & cream cheese ': 0.013726487036095577,
#  'other vegetables & citrus fruit': 0.02887646161667514,
#  'pork & root vegetables': 0.01362480935434672,
#  'frankfurter & root vegetables': 0.010167768174885612,
#  'frankfurter & yogurt': 0.011184544992374174,
#  'root vegetables & yogurt': 0.025826131164209457,
#  'root vegetables & citrus fruit': 0.017691916624300967,
#  'yogurt & cream cheese ': 0.012404677173360447,
#  'yogurt & citrus fruit': 0.021657346212506354}

# %%
print(len(results))
# Out:
# 213

# %% [markdown]
# ### Putting the Results Well Organised into a Pandas DataFrame

# %%
results_DataFrame = pd.DataFrame(rule_supports.items(), columns=["Products", "Support"])

# %%
results_DataFrame
# Out:
#                            Products   Support
# 0                 beef & whole milk  0.021251
# 1                 beef & rolls/buns  0.013625
# 2           beef & other vegetables  0.019725
# 3            beef & root vegetables  0.017387
# 4                     beef & yogurt  0.011693
# ..                              ...       ...
# 208            frankfurter & yogurt  0.011185
# 209        root vegetables & yogurt  0.025826
# 210  root vegetables & citrus fruit  0.017692
# 211          yogurt & cream cheese   0.012405
# 212           yogurt & citrus fruit  0.021657
#
# [213 rows x 2 columns]

# %% [markdown]
# ### Displaying the Results Sorted by Support

# %%
results_DataFrame = results_DataFrame.sort_values("Support", ascending=False)
results_DataFrame
# Out:
#                                Products   Support
# 120       whole milk & other vegetables  0.074835
# 103             whole milk & rolls/buns  0.056634
# 125                 whole milk & yogurt  0.056024
# 124        whole milk & root vegetables  0.048907
# 201  other vegetables & root vegetables  0.047382
# ..                                  ...       ...
# 153            tropical fruit & napkins  0.010066
# 86           waffles & other vegetables  0.010066
# 18                sausage & frankfurter  0.010066
# 10      sausage & fruit/vegetable juice  0.010066
# 107            whole milk & hard cheese  0.010066
#
# [213 rows x 2 columns]

# %%
from google.colab import data_table

data_table.DataTable(results_DataFrame)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Products</th>
#       <th>Support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>120</th>
#       <td>whole milk &amp; other vegetables</td>
#       <td>0.074835</td>
#     </tr>
#     <tr>
#       <th>103</th>
#       <td>whole milk &amp; rolls/buns</td>
#       <td>0.056634</td>
#     </tr>
#     <tr>
#       <th>125</th>
#       <td>whole milk &amp; yogurt</td>
#       <td>0.056024</td>
#     </tr>
#     <tr>
#       <th>124</th>
#       <td>whole milk &amp; root vegetables</td>
#       <td>0.048907</td>
#     </tr>
#     <tr>
#       <th>201</th>
#       <td>other vegetables &amp; root vegetables</td>
#       <td>0.047382</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>153</th>
#       <td>tropical fruit &amp; napkins</td>
#       <td>0.010066</td>
#     </tr>
#     <tr>
#       <th>86</th>
#       <td>waffles &amp; other vegetables</td>
#       <td>0.010066</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>sausage &amp; frankfurter</td>
#       <td>0.010066</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>sausage &amp; fruit/vegetable juice</td>
#       <td>0.010066</td>
#     </tr>
#     <tr>
#       <th>107</th>
#       <td>whole milk &amp; hard cheese</td>
#       <td>0.010066</td>
#     </tr>
#   </tbody>
# </table>
# <p>213 rows × 2 columns</p>
# </div>
