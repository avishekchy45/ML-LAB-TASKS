# %% [markdown]
# ### Mounting Drive

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Importing Dataset

# %%
import numpy as np
import pandas as pd

dataset = pd.read_csv(
    "/content/drive/MyDrive/Dataset/MLL/groceries.csv", sep="\n", header=None
)[0].str.split(",", expand=True)
dataset.head()
# Out:
#                  0                    1               2   \
# 0      citrus fruit  semi-finished bread       margarine
# 1    tropical fruit               yogurt          coffee
# 2        whole milk                 None            None
# 3         pip fruit               yogurt   cream cheese
# 4  other vegetables           whole milk  condensed milk
#
#                          3     4     5     6     7     8     9   ...    22  \
# 0               ready soups  None  None  None  None  None  None  ...  None
# 1                      None  None  None  None  None  None  None  ...  None
# 2                      None  None  None  None  None  None  None  ...  None
# 3              meat spreads  None  None  None  None  None  None  ...  None
# 4  long life bakery product  None  None  None  None  None  None  ...  None
#
#      23    24    25    26    27    28    29    30    31
# 0  None  None  None  None  None  None  None  None  None
# 1  None  None  None  None  None  None  None  None  None
# 2  None  None  None  None  None  None  None  None  None
# 3  None  None  None  None  None  None  None  None  None
# 4  None  None  None  None  None  None  None  None  None
#
# [5 rows x 32 columns]

# %%
dataset.shape
# Out:
# (9835, 32)

# %% [markdown]
# ### Converting Pandas DataFrame into Lists of Transactions

# %%
transactions = []
for i in range(0, 9835):
    # transactions.append([str(dataset.values[i,j]) for j in range(0, 32)])
    transactions.append(
        [
            str(dataset.values[i, j])
            for j in range(0, 32)
            if str(dataset.values[i, j]) != "None"
        ]
    )
for i in range(0, 5):
    print(transactions[i])
# Out:
# ['citrus fruit', 'semi-finished bread', 'margarine', 'ready soups']
# ['tropical fruit', 'yogurt', 'coffee']
# ['whole milk']
# ['pip fruit', 'yogurt', 'cream cheese ', 'meat spreads']
# ['other vegetables', 'whole milk', 'condensed milk', 'long life bakery product']

# %% [markdown]
# ### Training the Apriori Model on the Dataset

# %%
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: apyori in /usr/local/lib/python3.7/dist-packages (1.1.2)

# %%
from apyori import apriori

# assotiation_rules = apriori(transactions = transactions, min_support = 0.002, min_confidence = 0.2, min_lift = 3, min_length = 2, max_length = 2)
assotiation_rules = apriori(
    transactions=transactions,
    min_support=0.003,
    min_confidence=0.2,
    min_lift=4,
    min_length=5,
    max_length=8,
)

# %%
results = list(assotiation_rules)
results
# Out:
# [RelationRecord(items=frozenset({'Instant food products', 'hamburger meat'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Instant food products'}), items_add=frozenset({'hamburger meat'}), confidence=0.379746835443038, lift=11.42143769597027)]),
#  RelationRecord(items=frozenset({'bottled beer', 'liquor'}), support=0.004677173360447382, ordered_statistics=[OrderedStatistic(items_base=frozenset({'liquor'}), items_add=frozenset({'bottled beer'}), confidence=0.4220183486238532, lift=5.240594013529793)]),
#  RelationRecord(items=frozenset({'sugar', 'flour'}), support=0.00498220640569395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'flour'}), items_add=frozenset({'sugar'}), confidence=0.28654970760233917, lift=8.46311223504206)]),
#  RelationRecord(items=frozenset({'processed cheese', 'white bread'}), support=0.004168784951703101, ordered_statistics=[OrderedStatistic(items_base=frozenset({'processed cheese'}), items_add=frozenset({'white bread'}), confidence=0.25153374233128833, lift=5.975445303932901)]),
#  RelationRecord(items=frozenset({'root vegetables', 'citrus fruit', 'beef'}), support=0.003863751906456533, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit', 'beef'}), items_add=frozenset({'root vegetables'}), confidence=0.45783132530120485, lift=4.200346160762454), OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit'}), items_add=frozenset({'beef'}), confidence=0.21839080459770116, lift=4.162545665151921)]),
#  RelationRecord(items=frozenset({'root vegetables', 'soda', 'beef'}), support=0.003965429588205389, ordered_statistics=[OrderedStatistic(items_base=frozenset({'soda', 'beef'}), items_add=frozenset({'root vegetables'}), confidence=0.48750000000000004, lift=4.472539645522389), OrderedStatistic(items_base=frozenset({'root vegetables', 'soda'}), items_add=frozenset({'beef'}), confidence=0.21311475409836067, lift=4.0619837336383275)]),
#  RelationRecord(items=frozenset({'root vegetables', 'tropical fruit', 'beef'}), support=0.0037620742247076767, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'beef'}), items_add=frozenset({'root vegetables'}), confidence=0.49333333333333335, lift=4.526057213930349)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'berries', 'whole milk'}), support=0.004270462633451958, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries', 'whole milk'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.36206896551724144, lift=5.050990462215702)]),
#  RelationRecord(items=frozenset({'root vegetables', 'butter', 'domestic eggs'}), support=0.003253685815963396, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'domestic eggs'}), items_add=frozenset({'butter'}), confidence=0.22695035460992907, lift=4.095516949703949)]),
#  RelationRecord(items=frozenset({'hygiene articles', 'butter', 'whole milk'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hygiene articles', 'whole milk'}), items_add=frozenset({'butter'}), confidence=0.2380952380952381, lift=4.296636085626911)]),
#  RelationRecord(items=frozenset({'onions', 'butter', 'whole milk'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'onions', 'whole milk'}), items_add=frozenset({'butter'}), confidence=0.25210084033613445, lift=4.549379384781435)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter', 'whipped/sour cream'}), support=0.005795627859684799, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'butter'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.2893401015228426, lift=4.036397019116535)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'butter', 'tropical fruit'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter', 'tropical fruit'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.30612244897959184, lift=4.270516717325228)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter milk', 'pip fruit'}), support=0.003253685815963396, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'butter milk'}), items_add=frozenset({'pip fruit'}), confidence=0.3137254901960784, lift=4.147164242040902)]),
#  RelationRecord(items=frozenset({'root vegetables', 'citrus fruit', 'chicken'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit', 'chicken'}), items_add=frozenset({'root vegetables'}), confidence=0.4411764705882353, lift=4.0475471905179985)]),
#  RelationRecord(items=frozenset({'chocolate', 'whole milk', 'long life bakery product'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whole milk', 'long life bakery product'}), items_add=frozenset({'chocolate'}), confidence=0.22556390977443608, lift=4.545944779982744)]),
#  RelationRecord(items=frozenset({'curd', 'yogurt', 'pip fruit'}), support=0.003863751906456533, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'yogurt'}), items_add=frozenset({'curd'}), confidence=0.21468926553672318, lift=4.0295208522016654)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'curd', 'yogurt'}), support=0.004575495678698526, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt'}), items_add=frozenset({'curd'}), confidence=0.22058823529411764, lift=4.140239110911541)]),
#  RelationRecord(items=frozenset({'other vegetables', 'herbs', 'root vegetables'}), support=0.003863751906456533, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs'}), items_add=frozenset({'other vegetables', 'root vegetables'}), confidence=0.23750000000000002, lift=5.012473175965666), OrderedStatistic(items_base=frozenset({'other vegetables', 'herbs'}), items_add=frozenset({'root vegetables'}), confidence=0.5, lift=4.5872201492537314)]),
#  RelationRecord(items=frozenset({'root vegetables', 'herbs', 'whole milk'}), support=0.004168784951703101, ordered_statistics=[OrderedStatistic(items_base=frozenset({'herbs'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.25625, lift=5.23954002079002), OrderedStatistic(items_base=frozenset({'herbs', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.5394736842105262, lift=4.949369108405341)]),
#  RelationRecord(items=frozenset({'other vegetables', 'root vegetables', 'whole milk', 'beef'}), support=0.003965429588205389, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'beef'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.20103092783505158, lift=4.110476455837282)]),
#  RelationRecord(items=frozenset({'other vegetables', 'root vegetables', 'whole milk', 'brown bread'}), support=0.00315200813421454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'brown bread'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.31000000000000005, lift=4.142459239130435)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter', 'domestic eggs', 'whole milk'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter', 'domestic eggs'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3157894736842105, lift=4.219822654462242), OrderedStatistic(items_base=frozenset({'other vegetables', 'butter', 'whole milk'}), items_add=frozenset({'domestic eggs'}), confidence=0.26548672566371684, lift=4.184394145677332), OrderedStatistic(items_base=frozenset({'other vegetables', 'domestic eggs', 'whole milk'}), items_add=frozenset({'butter'}), confidence=0.24793388429752064, lift=4.474183031313974)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter', 'whole milk', 'root vegetables'}), support=0.004168784951703101, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'butter'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.2081218274111675, lift=4.255463976276159), OrderedStatistic(items_base=frozenset({'root vegetables', 'butter'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3228346456692913, lift=4.313965679561794)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter', 'tropical fruit', 'whole milk'}), support=0.003355363497712252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.336734693877551, lift=4.499708850931677)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter', 'tropical fruit', 'yogurt'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.30612244897959184, lift=7.050853128136501), OrderedStatistic(items_base=frozenset({'butter', 'yogurt'}), items_add=frozenset({'other vegetables', 'tropical fruit'}), confidence=0.20833333333333334, lift=5.8044145420207744), OrderedStatistic(items_base=frozenset({'other vegetables', 'butter', 'yogurt'}), items_add=frozenset({'tropical fruit'}), confidence=0.4761904761904762, lift=4.5381136950904395), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'yogurt'}), items_add=frozenset({'butter'}), confidence=0.24793388429752064, lift=4.474183031313974)]),
#  RelationRecord(items=frozenset({'other vegetables', 'butter', 'whipped/sour cream', 'whole milk'}), support=0.003965429588205389, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'butter'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.39000000000000007, lift=5.21148097826087), OrderedStatistic(items_base=frozenset({'other vegetables', 'butter', 'whole milk'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.3451327433628319, lift=4.8147241574091515), OrderedStatistic(items_base=frozenset({'other vegetables', 'whipped/sour cream', 'whole milk'}), items_add=frozenset({'butter'}), confidence=0.27083333333333337, lift=4.887423547400612)]),
#  RelationRecord(items=frozenset({'root vegetables', 'butter', 'whole milk', 'yogurt'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'butter'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.23622047244094488, lift=4.216385383768952), OrderedStatistic(items_base=frozenset({'butter', 'yogurt'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.20833333333333334, lift=4.259788634788635)]),
#  RelationRecord(items=frozenset({'butter', 'tropical fruit', 'whole milk', 'yogurt'}), support=0.003355363497712252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'butter', 'tropical fruit'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.336734693877551, lift=6.010500388903292), OrderedStatistic(items_base=frozenset({'butter', 'yogurt'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.22916666666666666, lift=5.417918669871795)]),
#  RelationRecord(items=frozenset({'other vegetables', 'citrus fruit', 'tropical fruit', 'root vegetables'}), support=0.004473817996949669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit'}), items_add=frozenset({'other vegetables', 'tropical fruit'}), confidence=0.2528735632183908, lift=7.045358340659697), OrderedStatistic(items_base=frozenset({'citrus fruit', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'root vegetables'}), confidence=0.22448979591836735, lift=4.737890864500306), OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'citrus fruit'}), confidence=0.21256038647342995, lift=7.361026059740083), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'root vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.4313725490196078, lift=4.110997112023104), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'tropical fruit'}), items_add=frozenset({'root vegetables'}), confidence=0.4943820224719101, lift=4.535678349823915), OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit', 'tropical fruit'}), items_add=frozenset({'other vegetables'}), confidence=0.7857142857142856, lift=4.060693641618497), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}), items_add=frozenset({'citrus fruit'}), confidence=0.3636363636363636, lift=4.3935671208398475)]),
#  RelationRecord(items=frozenset({'other vegetables', 'citrus fruit', 'whole milk', 'root vegetables'}), support=0.005795627859684799, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.2007042253521127, lift=4.103796374923136), OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3275862068965517, lift=4.377459707646177), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.4453125, lift=4.085492945429104)]),
#  RelationRecord(items=frozenset({'other vegetables', 'citrus fruit', 'whipped/sour cream', 'whole milk'}), support=0.0036603965429588205, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'citrus fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3364485981308411, lift=4.495885818772856)]),
#  RelationRecord(items=frozenset({'root vegetables', 'citrus fruit', 'tropical fruit', 'whole milk'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.2011494252873563, lift=4.7555398983200705)]),
#  RelationRecord(items=frozenset({'other vegetables', 'cream cheese ', 'whole milk', 'yogurt'}), support=0.0034570411794611084, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'cream cheese '}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.2518518518518519, lift=4.495395577065269), OrderedStatistic(items_base=frozenset({'cream cheese ', 'whole milk'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.20987654320987653, lift=4.834041691965189)]),
#  RelationRecord(items=frozenset({'other vegetables', 'curd', 'tropical fruit', 'whole milk'}), support=0.00315200813421454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3069306930693069, lift=4.101444791218253)]),
#  RelationRecord(items=frozenset({'curd', 'tropical fruit', 'whole milk', 'yogurt'}), support=0.003965429588205389, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd', 'tropical fruit'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.3861386138613862, lift=6.8923289788143975), OrderedStatistic(items_base=frozenset({'curd', 'yogurt'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.2294117647058824, lift=5.423713235294119), OrderedStatistic(items_base=frozenset({'curd', 'tropical fruit', 'whole milk'}), items_add=frozenset({'yogurt'}), confidence=0.6093750000000001, lift=4.368223852040817), OrderedStatistic(items_base=frozenset({'tropical fruit', 'whole milk', 'yogurt'}), items_add=frozenset({'curd'}), confidence=0.26174496644295303, lift=4.912713253752754)]),
#  RelationRecord(items=frozenset({'other vegetables', 'domestic eggs', 'whole milk', 'root vegetables'}), support=0.004575495678698526, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'domestic eggs'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.20547945205479454, lift=4.201435365818928), OrderedStatistic(items_base=frozenset({'root vegetables', 'domestic eggs'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3191489361702128, lift=4.264714384828863)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'domestic eggs', 'whole milk'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'domestic eggs'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.35714285714285715, lift=4.77241847826087), OrderedStatistic(items_base=frozenset({'other vegetables', 'domestic eggs', 'whole milk'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.2892561983471074, lift=4.03522654006213)]),
#  RelationRecord(items=frozenset({'other vegetables', 'root vegetables', 'whole milk', 'frozen vegetables'}), support=0.003863751906456533, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'frozen vegetables'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.21714285714285714, lift=4.43991683991684), OrderedStatistic(items_base=frozenset({'root vegetables', 'frozen vegetables'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.33333333333333337, lift=4.454257246376812)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whole milk', 'fruit/vegetable juice', 'root vegetables'}), support=0.003965429588205389, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3305084745762712, lift=4.416509303610907)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whole milk', 'fruit/vegetable juice', 'yogurt'}), support=0.005083884087442806, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'fruit/vegetable juice'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.24154589371980675, lift=4.3114407708426485)]),
#  RelationRecord(items=frozenset({'onions', 'other vegetables', 'whole milk', 'root vegetables'}), support=0.003253685815963396, ordered_statistics=[OrderedStatistic(items_base=frozenset({'onions', 'other vegetables'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.22857142857142856, lift=4.673596673596673), OrderedStatistic(items_base=frozenset({'onions', 'root vegetables'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3440860215053763, lift=4.59794296400187), OrderedStatistic(items_base=frozenset({'onions', 'whole milk'}), items_add=frozenset({'other vegetables', 'root vegetables'}), confidence=0.2689075630252101, lift=5.675334511486998), OrderedStatistic(items_base=frozenset({'onions', 'other vegetables', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.4923076923076923, lift=4.516647531572905)]),
#  RelationRecord(items=frozenset({'other vegetables', 'pip fruit', 'tropical fruit', 'root vegetables'}), support=0.003355363497712252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'pip fruit'}), items_add=frozenset({'other vegetables', 'tropical fruit'}), confidence=0.21568627450980393, lift=6.009276231739155)]),
#  RelationRecord(items=frozenset({'other vegetables', 'pip fruit', 'whole milk', 'root vegetables'}), support=0.005490594814438231, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'pip fruit'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.21011673151750973, lift=4.29625375150667), OrderedStatistic(items_base=frozenset({'root vegetables', 'pip fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.35294117647058826, lift=4.716272378516624)]),
#  RelationRecord(items=frozenset({'other vegetables', 'pip fruit', 'tropical fruit', 'yogurt'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'pip fruit', 'yogurt'}), items_add=frozenset({'tropical fruit'}), confidence=0.4375, lift=4.169391957364341)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'pip fruit', 'whole milk'}), support=0.0036603965429588205, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'pip fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.39560439560439564, lift=5.286371237458194)]),
#  RelationRecord(items=frozenset({'other vegetables', 'rolls/buns', 'tropical fruit', 'root vegetables'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'rolls/buns', 'tropical fruit'}), items_add=frozenset({'root vegetables'}), confidence=0.45454545454545453, lift=4.17020013568521)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'tropical fruit', 'root vegetables'}), support=0.003355363497712252, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'root vegetables'}), confidence=0.2426470588235294, lift=5.121102625599596)]),
#  RelationRecord(items=frozenset({'other vegetables', 'tropical fruit', 'whole milk', 'root vegetables'}), support=0.007015760040671073, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.33333333333333337, lift=4.454257246376812)]),
#  RelationRecord(items=frozenset({'other vegetables', 'tropical fruit', 'yogurt', 'root vegetables'}), support=0.00498220640569395, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.23671497584541062, lift=5.452205591193474)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'whole milk', 'root vegetables'}), support=0.005185561769191663, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'whipped/sour cream'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.30357142857142855, lift=4.056555706521739)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'yogurt', 'root vegetables'}), support=0.0034570411794611084, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'whipped/sour cream'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.20238095238095238, lift=4.661397345823575)]),
#  RelationRecord(items=frozenset({'other vegetables', 'yogurt', 'whole milk', 'root vegetables'}), support=0.007829181494661922, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'yogurt'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.3031496062992126, lift=4.050918991783636)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'tropical fruit', 'whole milk'}), support=0.004473817996949669, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.32352941176470584, lift=4.323249680306905)]),
#  RelationRecord(items=frozenset({'other vegetables', 'whipped/sour cream', 'tropical fruit', 'yogurt'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.25735294117647056, lift=5.927555448408871), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'yogurt'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.2892561983471074, lift=4.03522654006213)]),
#  RelationRecord(items=frozenset({'pastry', 'tropical fruit', 'whole milk', 'yogurt'}), support=0.003050330452465684, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pastry', 'tropical fruit'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.23076923076923075, lift=4.119084182605054)]),
#  RelationRecord(items=frozenset({'root vegetables', 'pip fruit', 'tropical fruit', 'whole milk'}), support=0.00315200813421454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'pip fruit'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.20261437908496732, lift=4.790174082453494)]),
#  RelationRecord(items=frozenset({'root vegetables', 'pip fruit', 'whole milk', 'yogurt'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'pip fruit'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.22875816993464052, lift=4.083188024150979)]),
#  RelationRecord(items=frozenset({'pip fruit', 'tropical fruit', 'whole milk', 'yogurt'}), support=0.0037620742247076767, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pip fruit', 'yogurt'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.2090395480225989, lift=4.94207681442851)]),
#  RelationRecord(items=frozenset({'root vegetables', 'tropical fruit', 'whole milk', 'yogurt'}), support=0.0056939501779359435, ordered_statistics=[OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.2705314009661836, lift=4.828813663343767), OrderedStatistic(items_base=frozenset({'root vegetables', 'yogurt'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.2204724409448819, lift=5.212371290127195)]),
#  RelationRecord(items=frozenset({'tropical fruit', 'sausage', 'whole milk', 'yogurt'}), support=0.00315200813421454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'tropical fruit', 'sausage'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.22627737226277375, lift=4.038907361532449)]),
#  RelationRecord(items=frozenset({'whipped/sour cream', 'tropical fruit', 'whole milk', 'yogurt'}), support=0.004372140315200813, ordered_statistics=[OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'tropical fruit'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.3161764705882353, lift=5.6435491619515314), OrderedStatistic(items_base=frozenset({'whipped/sour cream', 'yogurt'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.2107843137254902, lift=4.983326263197587), OrderedStatistic(items_base=frozenset({'tropical fruit', 'whole milk', 'yogurt'}), items_add=frozenset({'whipped/sour cream'}), confidence=0.28859060402684567, lift=4.025941263268123)]),
#  RelationRecord(items=frozenset({'root vegetables', 'whole milk', 'other vegetables', 'citrus fruit', 'tropical fruit'}), support=0.00315200813421454, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'root vegetables'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.303921568627451, lift=7.185261123680243), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'tropical fruit'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.34831460674157305, lift=7.121983695017404), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'whole milk'}), items_add=frozenset({'root vegetables', 'tropical fruit'}), confidence=0.24218750000000003, lift=11.506831219806765), OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit', 'tropical fruit'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.5535714285714286, lift=7.397248641304349), OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit', 'whole milk'}), items_add=frozenset({'other vegetables', 'tropical fruit'}), confidence=0.34444444444444444, lift=9.59663204280768), OrderedStatistic(items_base=frozenset({'citrus fruit', 'tropical fruit', 'whole milk'}), items_add=frozenset({'root vegetables', 'other vegetables'}), confidence=0.34831460674157305, lift=7.351232097217534), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}), items_add=frozenset({'citrus fruit', 'whole milk'}), confidence=0.256198347107438, lift=8.399035812672176), OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit', 'whole milk'}), items_add=frozenset({'other vegetables', 'citrus fruit'}), confidence=0.2627118644067797, lift=9.097785867748867), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'whole milk', 'root vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.543859649122807, lift=5.183003535971713), OrderedStatistic(items_base=frozenset({'other vegetables', 'citrus fruit', 'tropical fruit', 'whole milk'}), items_add=frozenset({'root vegetables'}), confidence=0.6326530612244898, lift=5.804237739872069), OrderedStatistic(items_base=frozenset({'root vegetables', 'citrus fruit', 'tropical fruit', 'whole milk'}), items_add=frozenset({'other vegetables'}), confidence=0.8857142857142858, lift=4.577509196006306), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'whole milk', 'root vegetables'}), items_add=frozenset({'citrus fruit'}), confidence=0.44927536231884063, lift=5.428284015240538)]),
#  RelationRecord(items=frozenset({'root vegetables', 'whole milk', 'yogurt', 'other vegetables', 'tropical fruit'}), support=0.0035587188612099642, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'root vegetables'}), items_add=frozenset({'whole milk', 'yogurt'}), confidence=0.2892561983471074, lift=5.163039402438841), OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'root vegetables'}), items_add=frozenset({'tropical fruit', 'whole milk'}), confidence=0.2755905511811023, lift=6.515464112658994), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'whole milk'}), items_add=frozenset({'root vegetables', 'yogurt'}), confidence=0.20833333333333331, lift=8.066765091863516), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'yogurt'}), items_add=frozenset({'root vegetables', 'whole milk'}), confidence=0.2892561983471074, lift=5.914417278053642), OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit', 'whole milk'}), items_add=frozenset({'other vegetables', 'yogurt'}), confidence=0.2966101694915254, lift=6.8317588218949705), OrderedStatistic(items_base=frozenset({'root vegetables', 'tropical fruit', 'yogurt'}), items_add=frozenset({'other vegetables', 'whole milk'}), confidence=0.4375, lift=5.846212635869565), OrderedStatistic(items_base=frozenset({'root vegetables', 'whole milk', 'yogurt'}), items_add=frozenset({'other vegetables', 'tropical fruit'}), confidence=0.24475524475524477, lift=6.819172329087343), OrderedStatistic(items_base=frozenset({'tropical fruit', 'whole milk', 'yogurt'}), items_add=frozenset({'root vegetables', 'other vegetables'}), confidence=0.2348993288590604, lift=4.95758562087738), OrderedStatistic(items_base=frozenset({'other vegetables', 'yogurt', 'whole milk', 'root vegetables'}), items_add=frozenset({'tropical fruit'}), confidence=0.45454545454545453, lift=4.331835799859055), OrderedStatistic(items_base=frozenset({'other vegetables', 'tropical fruit', 'whole milk', 'yogurt'}), items_add=frozenset({'root vegetables'}), confidence=0.4666666666666667, lift=4.281405472636816)])]

# %%
# Number of rules
print(len(results))
# Out:
# 64

# %% [markdown]
# ### Putting the Results Well Organised into a Pandas DataFrame

# %%
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

results_DataFrame = pd.DataFrame(
    inspect(results),
    columns=["Left Hand Side", "Right Hand Side", "Support", "Confidence", "Lift"],
)

# %%
results_DataFrame
# Out:
#            Left Hand Side  Right Hand Side   Support  Confidence       Lift
# 0   Instant food products   hamburger meat  0.003050    0.379747  11.421438
# 1                  liquor     bottled beer  0.004677    0.422018   5.240594
# 2                   flour            sugar  0.004982    0.286550   8.463112
# 3        processed cheese      white bread  0.004169    0.251534   5.975445
# 4            citrus fruit  root vegetables  0.003864    0.457831   4.200346
# ..                    ...              ...       ...         ...        ...
# 59        root vegetables       whole milk  0.005694    0.270531   4.828814
# 60         tropical fruit       whole milk  0.003152    0.226277   4.038907
# 61     whipped/sour cream       whole milk  0.004372    0.316176   5.643549
# 62       other vegetables   tropical fruit  0.003152    0.303922   7.185261
# 63       other vegetables       whole milk  0.003559    0.289256   5.163039
#
# [64 rows x 5 columns]

# %% [markdown]
# ### Displaying the Results Sorted by Support

# %%
results_DataFrame = results_DataFrame.sort_values("Support", ascending=False)
results_DataFrame
# Out:
#            Left Hand Side     Right Hand Side   Support  Confidence       Lift
# 52        root vegetables    other vegetables  0.007829    0.303150   4.050919
# 48        root vegetables    other vegetables  0.007016    0.333333   4.454257
# 11       other vegetables  whipped/sour cream  0.005796    0.289340   4.036397
# 30       other vegetables     root vegetables  0.005796    0.200704   4.103796
# 59        root vegetables          whole milk  0.005694    0.270531   4.828814
# ..                    ...                 ...       ...         ...        ...
# 15             whole milk           chocolate  0.003050    0.225564   4.545945
# 22                 butter    other vegetables  0.003050    0.315789   4.219823
# 25                 butter    other vegetables  0.003050    0.306122   7.050853
# 27        root vegetables          whole milk  0.003050    0.236220   4.216385
# 0   Instant food products      hamburger meat  0.003050    0.379747  11.421438
#
# [64 rows x 5 columns]
